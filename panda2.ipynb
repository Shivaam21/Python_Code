# %%
import pandas as pd

# %%
df=pd.read_csv("Course Dataset",index_col="DATE",parse_dates=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.read_csv("Course Dataset",index_col="DATE",parse_dates=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df=pd.read_csv("Course Dataset.csv",index_col = "DATE",parse_dates = False)

# %%
df.head()
# Out:
#               Price
# DATE
# 01-01-1985  72.5052
# 02-01-1985  70.6720
# 03-01-1985  62.4502
# 04-01-1985  57.4714
# 05-01-1985  55.3151

# %%
df=pd.read_csv("Course Dataset.csv",index_col = "DATE",parse_dates = True)

# %%
df.head()
# Out:
#               Price
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
df.tail()
# Out:
#                Price
# DATE
# 2017-09-01   98.6154
# 2017-10-01   93.6137
# 2017-11-01   97.3359
# 2017-12-01  114.7212
# 2018-01-01  129.4048

# %%
df.shape
# Out:
# (397, 1)

# %%
df.plot(figsize=(12,8))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.plot(figsize=(12,8))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1886, in _get_plot_backend(backend)
#    1883 if backend_str in _backends:
#    1884     return _backends[backend_str]
# -> 1886 module = _load_backend(backend_str)
#    1887 _backends[backend_str] = module
# ...

# %%
df.plot(figsize=(12,8))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.plot(figsize=(12,8))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1886, in _get_plot_backend(backend)
#    1883 if backend_str in _backends:
#    1884     return _backends[backend_str]
# -> 1886 module = _load_backend(backend_str)
#    1887 _backends[backend_str] = module
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.plot(figsize=(12,8))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='DATE'>

# %%
start_date="01-01-2000"
end_date="01-01-2005"
timelim=(df.index>=start_date)&(df.index<end_date)
datanew=df.loc[timelim]

# %%
datanew.head()
# Out:
#                Price
# DATE
# 2000-01-01  102.2301
# 2000-02-01   94.2989
# 2000-03-01   88.0927
# 2000-04-01   81.4425
# 2000-05-01   84.4552

# %%
datanew.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
dataquarterly=df.rolling(window3).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dataquarterly=df.rolling(window3).mean()
#
# NameError: name 'window3' is not defined

# %%
dataquarterly=df.rolling(window 3).mean()
# Out:
#   Cell In[27], line 1
#     dataquarterly=df.rolling(window 3).mean()
#                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dataquarterly=df.rolling(window=3).mean()

# %%
dataquarterly.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
datayearly=df.rolling(window=12).mean()

# %%
datayearly.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
from pandas.plotting import lag_plot
lag_plot(df["Price"])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>
